# %% [markdown]
# # Model
# In the dataset, each sample corresponds to an insurance policy, i.e. a contract within an insurance company and an individual (policyholder). Available features include driver age, vehicle age, vehicle power, etc. Insurance companies aim to predict the pure premium, which is the expected total claim amount per unit of exposure (e.g., per year) for each policyholder.
# - Goal: Predict insurance claim costs (pure premium) per policy.
# - Approach 1:
#     - Model claim frequency using Poisson regression.
#     - Model claim severity using Gamma regression.
#     - Combine both to estimate pure premiums.
# - Approach 2:
#     - Model the total claim amount per exposure directly, with a Tweedie distribution.
#
# ## Some insurance concepts
# In auto insurance (which this dataset models), each policy represents a contract between the insurer and a driver, usually for a 1-year period.
# Each policy has:
# - Exposure: How long the policy was active (e.g., 1 year = full exposure, 0.5 = half-year).
# - ClaimNb: The number of claims made during that time.
# - ClaimAmount: The total money paid out by the insurer for those claims.
#
# Other concepts:
# - Frequency = ClaimNb / Exposure
#
# This tells us how often claims happen per year "claims per unit of time".
#
# - AvgClaimAmount = ClaimAmount / max(ClaimNb, 1)
#
# This tells us how big each claim is, on average.
#
#
# - PurePremium = ClaimAmount / Exposure
#
# This is the key target: how much money the insurer expects to pay per year for this policy.
# It’s a combination of how often the person claims and how expensive each claim is.
#
# ## Poisson distribution
# The Poisson distribution models the probability of a given number of events occurring in a fixed interval of time or space — assuming the events happen independently and at a constant rate.
# - Models counts, so can only be possitive
# - assumes mean = variance, so lower ocurrences mean smaller distribution.
#
#
# In Poisson regression, we estimate λ for each observation based on features. If λ (lambda) is the expected number of events, then:
# P(Y = y) = (λ^y * e^-λ) / y!
#
# However, instead of modeling λ directly, we model the log of λ as a linear function of features:
#
# log(λ) = β₀ + β₁·X₁ + β₂·X₂ + ... + βn·Xn
#
#
# So:
#
# λ = exp(β₀ + β₁·X₁ + β₂·X₂ + ...)
#
# This ensures λ is always positive, as expected for a count.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import arff
import seaborn as sns

from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    mean_tweedie_deviance,
)

# %% [markdown]
# ## Quick inspection of datasets

# %%
# Load frequency dataset
with open('freMTPL2freq.arff', 'r') as f:
    data = arff.load(f)
    
df_freq = pd.DataFrame(data['data'], columns=[attr[0] for attr in data['attributes']])
df_freq["IDpol"] = df_freq["IDpol"].astype(int) # Set as integer (not float)
df_freq.set_index("IDpol", inplace=True) # Set IDpol (policy id) as index

# Load severity dataset
with open('freMTPL2sev.arff', 'r') as f:
    data = arff.load(f)
 
df_sev = pd.DataFrame(data['data'], columns=[attr[0] for attr in data['attributes']])
df_sev["IDpol"] = df_sev["IDpol"].astype(int)

# %%
print(df_freq.info())
df_freq.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 678013 entries, 1 to 6114330
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   ClaimNb     678013 non-null  float64
#  1   Exposure    678013 non-null  float64
#  2   Area        678013 non-null  object
#  3   VehPower    678013 non-null  float64
#  4   VehAge      678013 non-null  float64
#  5   DrivAge     678013 non-null  float64
#  6   BonusMalus  678013 non-null  float64
#  7   VehBrand    678013 non-null  object
#  8   VehGas      678013 non-null  object
#  9   Density     678013 non-null  float64
#  10  Region      678013 non-null  object
# dtypes: float64(7), object(4)
# memory usage: 62.1+ MB
# None
#        ClaimNb  Exposure Area  VehPower  VehAge  DrivAge  BonusMalus VehBrand  \
# IDpol
# 1          1.0      0.10    D       5.0     0.0     55.0        50.0      B12
# 3          1.0      0.77    D       5.0     0.0     55.0        50.0      B12
# ...

# %%
df_freq['ClaimNb'].value_counts()
# Out:
# ClaimNb
# 0.0     643953
# 1.0      32178
# 2.0       1784
# 3.0         82
# 4.0          7
# 11.0         3
# 5.0          2
# 6.0          1
# 8.0          1
# 16.0         1
# 9.0          1
# Name: count, dtype: int64

# %%
print(df_sev.info())
print(f"Number of unique IDpol: {df_sev['IDpol'].nunique()}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26639 entries, 0 to 26638
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   IDpol        26639 non-null  int64
#  1   ClaimAmount  26639 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 416.4 KB
# None
# Number of unique IDpol: 24950

# %%
# Merge the two datasets
df_sev = df_sev.groupby("IDpol").sum() # sum ClaimAmount over identical IDs (So that ClaimAmount = total ClaimAmount for each policy)

df = df_freq.join(df_sev, how="left")
print(f"Out of {len(df)} policies {len(df[df.ClaimAmount.isnull()])} have no ClaimAmount, that is {round(((678013-673624)/678013)*100,2)}% of policies result in claimed money")

df["ClaimAmount"] = df["ClaimAmount"].fillna(0) # Claims with no ClaimAmount are set to 0
df.sample(5)
# Out:
# Out of 678013 policies 653069 have no ClaimAmount, that is 0.65% of policies result in claimed money
#          ClaimNb  Exposure Area  VehPower  VehAge  DrivAge  BonusMalus  \
# IDpol
# 125648       0.0      0.59    A       8.0    17.0     59.0        62.0
# 104291       0.0      0.12    D       4.0     9.0     48.0        50.0
# 165127       0.0      0.65    D       5.0     5.0     39.0        50.0
# 3088434      0.0      1.00    C       6.0     5.0     47.0        57.0
# 4148150      0.0      1.00    A      10.0     8.0     38.0        50.0
#
#         VehBrand   VehGas  Density Region  ClaimAmount
# IDpol
# 125648        B2   Diesel     15.0    R24          0.0
# 104291        B5  Regular   1313.0    R24          0.0
# 165127        B4   Diesel    634.0    R53          0.0
# 3088434       B2   Diesel    222.0    R24          0.0
# 4148150       B5  Regular     22.0    R24          0.0

# %%
df.describe(include="all")
# Out:
#               ClaimNb       Exposure    Area       VehPower         VehAge  \
# count   678013.000000  678013.000000  678013  678013.000000  678013.000000
# unique            NaN            NaN       6            NaN            NaN
# top               NaN            NaN       C            NaN            NaN
# freq              NaN            NaN  191880            NaN            NaN
# mean         0.053247       0.528750     NaN       6.454631       7.044265
# std          0.240117       0.364442     NaN       2.050906       5.666232
# min          0.000000       0.002732     NaN       4.000000       0.000000
# 25%          0.000000       0.180000     NaN       5.000000       2.000000
# 50%          0.000000       0.490000     NaN       6.000000       6.000000
# 75%          0.000000       0.990000     NaN       7.000000      11.000000
# max         16.000000       2.010000     NaN      15.000000     100.000000
#
# ...

# %% [markdown]
# ## Exploratory analysis

# %%
sns.histplot(df[df["ClaimAmount"] > 0]["ClaimAmount"])
plt.yscale("log")
plt.title("Distribution of Claim Amounts (log scale)")
# Out:
# Text(0.5, 1.0, 'Distribution of Claim Amounts (log scale)')

# %%
from functools import partial

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn.datasets import fetch_openml
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    mean_tweedie_deviance,
)


def load_mtpl2(n_samples=None):
    """Fetch the French Motor Third-Party Liability Claims dataset.

    Parameters
    ----------
    n_samples: int, default=None
      number of samples to select (for faster run time). Full dataset has
      678013 samples.
    """
    # freMTPL2freq dataset from https://www.openml.org/d/41214
    with open('freMTPL2freq.arff', 'r') as f:
        data = arff.load(f)
    df_freq = pd.DataFrame(data['data'], columns=[attr[0] for attr in data['attributes']])
        
    df_freq["IDpol"] = df_freq["IDpol"].astype(int)
    df_freq.set_index("IDpol", inplace=True)

    # freMTPL2sev dataset from https://www.openml.org/d/41215
    with open('freMTPL2sev.arff', 'r') as f:
        data = arff.load(f)
    df_sev = pd.DataFrame(data['data'], columns=[attr[0] for attr in data['attributes']])

    # sum ClaimAmount over identical IDs
    df_sev = df_sev.groupby("IDpol").sum()

    df = df_freq.join(df_sev, how="left")
    df["ClaimAmount"] = df["ClaimAmount"].fillna(0)

    # unquote string fields
    for column_name in df.columns[[t is object for t in df.dtypes.values]]:
        df[column_name] = df[column_name].str.strip("'")
    return df.iloc[:n_samples]


def plot_obs_pred(
    df,
    feature,
    weight,
    observed,
    predicted,
    y_label=None,
    title=None,
    ax=None,
    fill_legend=False,
):
    """Plot observed and predicted - aggregated per feature level.

    Parameters
    ----------
    df : DataFrame
        input data
    feature: str
        a column name of df for the feature to be plotted
    weight : str
        column name of df with the values of weights or exposure
    observed : str
        a column name of df with the observed target
    predicted : DataFrame
        a dataframe, with the same index as df, with the predicted target
    fill_legend : bool, default=False
        whether to show fill_between legend
    """
    # aggregate observed and predicted variables by feature level
    df_ = df.loc[:, [feature, weight]].copy()
    df_["observed"] = df[observed] * df[weight]
    df_["predicted"] = predicted * df[weight]
    df_ = (
        df_.groupby([feature])[[weight, "observed", "predicted"]]
        .sum()
        .assign(observed=lambda x: x["observed"] / x[weight])
        .assign(predicted=lambda x: x["predicted"] / x[weight])
    )

    ax = df_.loc[:, ["observed", "predicted"]].plot(style=".", ax=ax)
    y_max = df_.loc[:, ["observed", "predicted"]].values.max() * 0.8
    p2 = ax.fill_between(
        df_.index,
        0,
        y_max * df_[weight] / df_[weight].values.max(),
        color="g",
        alpha=0.1,
    )
    if fill_legend:
        ax.legend([p2], ["{} distribution".format(feature)])
    ax.set(
        ylabel=y_label if y_label is not None else None,
        title=title if title is not None else "Train: Observed vs Predicted",
    )


def score_estimator(
    estimator,
    X_train,
    X_test,
    df_train,
    df_test,
    target,
    weights,
    tweedie_powers=None,
):
    """Evaluate an estimator on train and test sets with different metrics"""

    metrics = [
        ("D² explained", None),  # Use default scorer if it exists
        ("mean abs. error", mean_absolute_error),
        ("mean squared error", mean_squared_error),
    ]
    if tweedie_powers:
        metrics += [
            (
                "mean Tweedie dev p={:.4f}".format(power),
                partial(mean_tweedie_deviance, power=power),
            )
            for power in tweedie_powers
        ]

    res = []
    for subset_label, X, df in [
        ("train", X_train, df_train),
        ("test", X_test, df_test),
    ]:
        y, _weights = df[target], df[weights]
        for score_label, metric in metrics:
            if isinstance(estimator, tuple) and len(estimator) == 2:
                # Score the model consisting of the product of frequency and
                # severity models.
                est_freq, est_sev = estimator
                y_pred = est_freq.predict(X) * est_sev.predict(X)
            else:
                y_pred = estimator.predict(X)

            if metric is None:
                if not hasattr(estimator, "score"):
                    continue
                score = estimator.score(X, y, sample_weight=_weights)
            else:
                score = metric(y, y_pred, sample_weight=_weights)

            res.append({"subset": subset_label, "metric": score_label, "score": score})

    res = (
        pd.DataFrame(res)
        .set_index(["metric", "subset"])
        .score.unstack(-1)
        .round(4)
        .loc[:, ["train", "test"]]
    )
    return res

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import (
    FunctionTransformer,
    KBinsDiscretizer,
    OneHotEncoder,
    StandardScaler,
)

df = load_mtpl2()


# Correct for unreasonable observations (that might be data error)
# and a few exceptionally large claim amounts
df["ClaimNb"] = df["ClaimNb"].clip(upper=4)
df["Exposure"] = df["Exposure"].clip(upper=1)
df["ClaimAmount"] = df["ClaimAmount"].clip(upper=200000)
# If the claim amount is 0, then we do not count it as a claim. The loss function
# used by the severity model needs strictly positive claim amounts. This way
# frequency and severity are more consistent with each other.
df.loc[(df["ClaimAmount"] == 0) & (df["ClaimNb"] >= 1), "ClaimNb"] = 0

log_scale_transformer = make_pipeline(
    FunctionTransformer(func=np.log), StandardScaler()
)

column_trans = ColumnTransformer(
    [
        (
            "binned_numeric",
            KBinsDiscretizer(n_bins=10, random_state=0),
            ["VehAge", "DrivAge"],
        ),
        (
            "onehot_categorical",
            OneHotEncoder(),
            ["VehBrand", "VehPower", "VehGas", "Region", "Area"],
        ),
        ("passthrough_numeric", "passthrough", ["BonusMalus"]),
        ("log_scaled_numeric", log_scale_transformer, ["Density"]),
    ],
    remainder="drop",
)
X = column_trans.fit_transform(df)

# Insurances companies are interested in modeling the Pure Premium, that is
# the expected total claim amount per unit of exposure for each policyholder
# in their portfolio:
df["PurePremium"] = df["ClaimAmount"] / df["Exposure"]

# This can be indirectly approximated by a 2-step modeling: the product of the
# Frequency times the average claim amount per claim:
df["Frequency"] = df["ClaimNb"] / df["Exposure"]
df["AvgClaimAmount"] = df["ClaimAmount"] / np.fmax(df["ClaimNb"], 1)

with pd.option_context("display.max_columns", 15):
    print(df[df.ClaimAmount > 0].head())
# Out:
#        ClaimNb  Exposure Area  VehPower  VehAge  DrivAge  BonusMalus VehBrand  \
# IDpol
# 139.0      1.0      0.75    F       7.0     1.0     61.0        50.0      B12
# 190.0      1.0      0.14    B      12.0     5.0     50.0        60.0      B12
# 414.0      1.0      0.14    E       4.0     0.0     36.0        85.0      B12
# 424.0      2.0      0.62    F      10.0     0.0     51.0       100.0      B12
# 463.0      1.0      0.31    A       5.0     0.0     45.0        50.0      B12
#
#         VehGas  Density Region  ClaimAmount   PurePremium  Frequency  \
# IDpol
# 139.0  Regular  27000.0    R11       303.00    404.000000   1.333333
# 190.0   Diesel     56.0    R25      1981.84  14156.000000   7.142857
# 414.0  Regular   4792.0    R11      1456.55  10403.928571   7.142857
# 424.0  Regular  27000.0    R11     10834.00  17474.193548   3.225806
# 463.0  Regular     12.0    R73      3986.67  12860.225806   3.225806
#
#        AvgClaimAmount
# IDpol
# 139.0          303.00
# ...
